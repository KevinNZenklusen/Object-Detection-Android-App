# %%
# !pip install ultralytics

# %%
import torch
print(torch.__version__)
# Out:
# 2.4.0+cpu

# %%
from ultralytics import YOLO

# Load a model
model = YOLO('yolov9t.pt')  # load a pretrained model (recommended for training)

# Train the model with CPU
results = model.train(data='data.yaml', epochs=100, imgsz=640, batch=4, device = 'cpu', single_cls=True)
# Out:
# ...
# 100%|██████████| 4.74M/4.74M [00:00<00:00, 10.3MB/s]
# New https://pypi.org/project/ultralytics/8.2.76 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.74  Python-3.10.11 torch-2.3.0+cpu CPU (AMD Ryzen 5 5600G with Radeon Graphics)
# ...

# %%
# Validate model

from ultralytics import YOLO

# Load a model (YoloV9)
model = YOLO('runs/detect/train7/weights/best.pt')  # load a custom model

# Validate the model
metrics = model.val()  # no arguments needed, dataset and settings remembered
metrics.box.map    # map50-95
metrics.box.map50  # map50
metrics.box.map75  # map75
metrics.box.maps   # a list contains map50-95 of each category
# Out:
# Ultralytics YOLOv8.2.74  Python-3.10.11 torch-2.3.0+cpu CPU (AMD Ryzen 5 5600G with Radeon Graphics)
# YOLOv9t summary (fused): 486 layers, 1,970,979 parameters, 0 gradients, 7.6 GFLOPs
# val: Scanning C:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\valid\labels.cache... 71 images, 0 backgrounds, 0 corrupt: 100%|██████████| 71/71 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 5/5 [00:06<00:00,  1.21s/it]
#                    all         71         75      0.994      0.947      0.949      0.834
# Speed: 1.4ms preprocess, 74.8ms inference, 0.0ms loss, 0.3ms postprocess per image
# Results saved to runs\detect\val6
# array([    0.83387])

# %%
#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train7/weights/best.pt')

# Run inference
model.predict('DatasetV8/test/images', save=True, imgsz=640, conf=0.2)
# Out:
# image 1/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.02105cc88f4f56199c90a9b0924ac3fa.jpg: 640x640 1 tv, 113.0ms
# image 2/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.913750077d8f0eec5ee7d9914061ff19.jpg: 640x640 1 tv, 107.0ms
# image 3/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.92ceb501f025369bdf92cc4c2feb2678.jpg: 640x640 1 tv, 119.0ms
# image 4/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.c32e63eba0631f73c5562102eef735f5.jpg: 640x640 1 tv, 107.0ms
# image 5/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\images-1-_jpg.rf.4c5fe257d07bb273a0aa4e972efd28e8.jpg: 640x640 3 tvs, 113.0ms
# ...

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- -----------
# absl-py                      2.1.0
# asttokens                    2.4.1
# astunparse                   1.6.3
# cachetools                   5.4.0
# certifi                      2024.7.4
# charset-normalizer           3.3.2
# colorama                     0.4.6
# coloredlogs                  15.0.1
# comm                         0.2.2
# contourpy                    1.2.1
# cycler                       0.12.1
# debugpy                      1.8.5
# decorator                    5.1.1
# exceptiongroup               1.2.2
# executing                    2.0.1
# filelock                     3.15.4
# flatbuffers                  24.3.25
# fonttools                    4.53.1
# fsspec                       2024.6.1
# gast                         0.4.0
# google-auth                  2.33.0
# google-auth-oauthlib         1.0.0
# google-pasta                 0.2.0
# grpcio                       1.65.4
# ...

# %%
#  Export model to tflite


from ultralytics import YOLO

# Load a model
model = YOLO('runs/detect/train7/weights/best.pt')  # load a custom trained model

# Export the model
model.export(format='tflite')
# Out:
# Ultralytics YOLOv8.2.74  Python-3.10.11 torch-2.3.0+cpu CPU (AMD Ryzen 5 5600G with Radeon Graphics)
# YOLOv9t summary (fused): 486 layers, 1,970,979 parameters, 0 gradients, 7.6 GFLOPs
#
# PyTorch: starting from 'runs\detect\train7\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 5, 8400) (4.4 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.16.2...
#
# ONNX: starting export with onnx 1.14.0 opset 17...
# ONNX: slimming with onnxslim 0.1.32...
# ONNX: export success  3.5s, saved as 'runs\detect\train7\weights\best.onnx' (8.0 MB)
# TensorFlow SavedModel: starting TFLite export with onnx2tf 1.22.3...
# TensorFlow SavedModel: export success  24.4s, saved as 'runs\detect\train7\weights\best_saved_model' (20.0 MB)
#
# TensorFlow Lite: starting export with tensorflow 2.16.2...
# TensorFlow Lite: export success  0.0s, saved as 'runs\detect\train7\weights\best_saved_model\best_float32.tflite' (7.8 MB)
#
# Export complete (26.4s)
# ...

# %%
# Prediction using custom tflite model

#  Prediction using trained model

from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train7/weights/best_saved_model/best_float32.tflite')

# Run inference
model.predict('DatasetV8/test/images', save=True, imgsz=640, conf=0.2)
# Out:
# Loading runs\detect\train7\weights\best_saved_model\best_float32.tflite for TensorFlow Lite inference...
#
# image 1/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.02105cc88f4f56199c90a9b0924ac3fa.jpg: 640x640 1 tv, 134.0ms
# image 2/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.913750077d8f0eec5ee7d9914061ff19.jpg: 640x640 1 tv, 111.0ms
# image 3/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.92ceb501f025369bdf92cc4c2feb2678.jpg: 640x640 1 tv, 126.0ms
# image 4/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\download-19-_jpg.rf.c32e63eba0631f73c5562102eef735f5.jpg: 640x640 1 tv, 112.0ms
# image 5/36 c:\Users\Kev9n\OneDrive\Documentos\TV-Screen-Object-Detection\DatasetV8\test\images\images-1-_jpg.rf.4c5fe257d07bb273a0aa4e972efd28e8.jpg: 640x640 3 tvs, 120.0ms
# ...
